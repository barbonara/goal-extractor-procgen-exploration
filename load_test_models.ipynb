# %%
import torch
import procgen
import procgen_tools
from procgen_tools.utils import setup

from procgen_tools.imports import *
from procgen_tools import visualization, patch_utils, maze, vfield
#setup(dl_data=True) # create directory structure and download data
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load models:
policy1, hook1 = load_model('15', 15)
policy2, hook2 = load_model('1', 15)
AX_SIZE = 3

# %%
seed = 7


def compare_component_probabilities(seed=seed, hook_0=hook, name='Model'):
    fig, axs = plt.subplots(1, 2, figsize=(2*AX_SIZE, 2*AX_SIZE))
    venv = maze.create_venv(num=1, start_level=seed, num_levels=1)
    vf = vfield.vector_field(venv, policy=hook_0.network)
    vfield.plot_vf(vf, ax=axs[0], show_components=True)
    axs[0].set_title('Action component vectors, {}'.format(name))
    
    vfield.plot_vf(vf, ax=axs[1], show_components=False)
    axs[1].set_title('Net probability vectors, {}'.format(name))

compare_component_probabilities(seed, hook1, "M_15")
compare_component_probabilities(seed, hook2, "M_1")
